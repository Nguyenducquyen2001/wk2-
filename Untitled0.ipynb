# %%
value1= input('nhap vao so thu 1 ');
value2= input('nhap vao so thu 2 ');
int(value1) + int(value2)
# Out:
# nhap vao so thu 1 2
# nhap vao so thu 2 10
# 12

# %%
with open('text.txt',mode='w') as acc:
  acc.write('20146148 gnd 88\n')
  acc.write('20146457 adg 45\n')
  acc.write('20146451 fds 48\n')
  acc.write('20146357 sfb 65\n')
  acc.write('20146951 sdg 36\n')
  acc.write('20146789 ght 85\n')
  acc.write('20146456 qew 52\n')
  acc.write('20146123 fgh 89\n')
  acc.write('20146258 ghy 32\n')

# %%
# with open('text.txt',mode='w') as account:
#     print('20146148 gnd 88\n',file = th)

# %%
# with open('text.txt',mode='w') as acc:
#   print(f'.{"mssv":<18}{"name":<20}{"sorce":>4}')
#   for recode in acc:
#     mssv, mane, surce = recode.split()
#     print(f'.{"mssv":<18}{"name":<20}{"sorce":>4}')

# %%
import pandas as pd
url = 'Book1.csv'
dataframe = pd.read_csv(url)
dataframe.head(20)
# Out:
#         mssv      ho va ten  khóa khoa  diem
# 0   20146456   nguyễn văn 1    20  ckm     5
# 1   20146148   nguyễn văn 2    20  ckm     4
# 2   20146125   nguyễn văn 3    20  ckm     6
# 3   20146204   nguyễn văn 4    20  ckm     7
# 4   20146235   nguyễn văn 5    20  ckm     8
# 5   19146789   nguyễn văn 6    19  ckm     9
# 6   19146357   nguyễn văn 7    19  ckm     5
# 7   19146852   nguyễn văn 8    19  ckm     6
# 8   19146357   nguyễn văn 9    19  ckm     8
# 9   19146235  nguyễn văn 10    19  ckm     9
# 10  20146951  nguyễn văn 11    20  ckm     7
# 11  20146257  nguyễn văn 12    20  ckm     8
# 12  20146146  nguyễn văn 13    20  ckm     9
# 13  20146125  nguyễn văn 14    20  ckm     7
# 14  20146256  nguyễn văn 15    20  ckm     9
# 15  19146589  nguyễn văn 16    19  ckm     8
# 16  19146851  nguyễn văn 17    19  ckm     7
# 17  19146539  nguyễn văn 18    19  ckm     6
# 18  19146756  nguyễn văn 19    19  ckm     9
# 19  19146124  nguyễn văn 20    19  ckm    10

# %%
dataframe.iloc[0:4]
# Out:
#        mssv     ho va ten  khóa khoa  diem
# 0  20146456  nguyễn văn 1    20  ckm     5
# 1  20146148  nguyễn văn 2    20  ckm     4
# 2  20146125  nguyễn văn 3    20  ckm     6
# 3  20146204  nguyễn văn 4    20  ckm     7

# %%
frame = dataframe.set_index(dataframe['ho va ten'])
frame.loc['nguyễn văn 3']
# Out:
# mssv             20146125
# ho va ten    nguyễn văn 3
# khóa                   20
# khoa                  ckm
# diem                    6
# Name: nguyễn văn 3, dtype: object

# %%
dataframe[dataframe['khoa']=='ckm'].head(10)
# Out:
#        mssv      ho va ten  khóa khoa  diem
# 0  20146456   nguyễn văn 1    20  ckm     5
# 1  20146148   nguyễn văn 2    20  ckm     4
# 2  20146125   nguyễn văn 3    20  ckm     6
# 3  20146204   nguyễn văn 4    20  ckm     7
# 4  20146235   nguyễn văn 5    20  ckm     8
# 5  19146789   nguyễn văn 6    19  ckm     9
# 6  19146357   nguyễn văn 7    19  ckm     5
# 7  19146852   nguyễn văn 8    19  ckm     6
# 8  19146357   nguyễn văn 9    19  ckm     8
# 9  19146235  nguyễn văn 10    19  ckm     9

# %%
dataframe[(dataframe['khoa']=='ckm')&(dataframe['khóa']==19)]
# Out:
#         mssv      ho va ten  khóa khoa  diem
# 5   19146789   nguyễn văn 6    19  ckm     9
# 6   19146357   nguyễn văn 7    19  ckm     5
# 7   19146852   nguyễn văn 8    19  ckm     6
# 8   19146357   nguyễn văn 9    19  ckm     8
# 9   19146235  nguyễn văn 10    19  ckm     9
# 15  19146589  nguyễn văn 16    19  ckm     8
# 16  19146851  nguyễn văn 17    19  ckm     7
# 17  19146539  nguyễn văn 18    19  ckm     6
# 18  19146756  nguyễn văn 19    19  ckm     9
# 19  19146124  nguyễn văn 20    19  ckm    10

# %%
dataframe['diem'].sum()
# Out:
# 147

# %%
dataframe['diem'].min()
# Out:
# 4

# %%
dataframe['diem'].max()
# Out:
# 10

# %%
dataframe.drop('khoa',axis=1).head(20)
# Out:
#         mssv      ho va ten  khóa  diem
# 0   20146456   nguyễn văn 1    20     5
# 1   20146148   nguyễn văn 2    20     4
# 2   20146125   nguyễn văn 3    20     6
# 3   20146204   nguyễn văn 4    20     7
# 4   20146235   nguyễn văn 5    20     8
# 5   19146789   nguyễn văn 6    19     9
# 6   19146357   nguyễn văn 7    19     5
# 7   19146852   nguyễn văn 8    19     6
# 8   19146357   nguyễn văn 9    19     8
# 9   19146235  nguyễn văn 10    19     9
# 10  20146951  nguyễn văn 11    20     7
# 11  20146257  nguyễn văn 12    20     8
# 12  20146146  nguyễn văn 13    20     9
# 13  20146125  nguyễn văn 14    20     7
# 14  20146256  nguyễn văn 15    20     9
# 15  19146589  nguyễn văn 16    19     8
# 16  19146851  nguyễn văn 17    19     7
# 17  19146539  nguyễn văn 18    19     6
# 18  19146756  nguyễn văn 19    19     9
# 19  19146124  nguyễn văn 20    19    10

# %%
dataframe.drop(['khoa','khóa'],axis=1).head(20)
# Out:
#         mssv      ho va ten  diem
# 0   20146456   nguyễn văn 1     5
# 1   20146148   nguyễn văn 2     4
# 2   20146125   nguyễn văn 3     6
# 3   20146204   nguyễn văn 4     7
# 4   20146235   nguyễn văn 5     8
# 5   19146789   nguyễn văn 6     9
# 6   19146357   nguyễn văn 7     5
# 7   19146852   nguyễn văn 8     6
# 8   19146357   nguyễn văn 9     8
# 9   19146235  nguyễn văn 10     9
# 10  20146951  nguyễn văn 11     7
# 11  20146257  nguyễn văn 12     8
# 12  20146146  nguyễn văn 13     9
# 13  20146125  nguyễn văn 14     7
# 14  20146256  nguyễn văn 15     9
# 15  19146589  nguyễn văn 16     8
# 16  19146851  nguyễn văn 17     7
# 17  19146539  nguyễn văn 18     6
# 18  19146756  nguyễn văn 19     9
# 19  19146124  nguyễn văn 20    10

# %%
dataframe.drop(dataframe.columns[2:4],axis=1).head(20)#xoa cot
# Out:
#         mssv      ho va ten  diem
# 0   20146456   nguyễn văn 1     5
# 1   20146148   nguyễn văn 2     4
# 2   20146125   nguyễn văn 3     6
# 3   20146204   nguyễn văn 4     7
# 4   20146235   nguyễn văn 5     8
# 5   19146789   nguyễn văn 6     9
# 6   19146357   nguyễn văn 7     5
# 7   19146852   nguyễn văn 8     6
# 8   19146357   nguyễn văn 9     8
# 9   19146235  nguyễn văn 10     9
# 10  20146951  nguyễn văn 11     7
# 11  20146257  nguyễn văn 12     8
# 12  20146146  nguyễn văn 13     9
# 13  20146125  nguyễn văn 14     7
# 14  20146256  nguyễn văn 15     9
# 15  19146589  nguyễn văn 16     8
# 16  19146851  nguyễn văn 17     7
# 17  19146539  nguyễn văn 18     6
# 18  19146756  nguyễn văn 19     9
# 19  19146124  nguyễn văn 20    10

# %%
dataframe[dataframe['khóa']!=19].head(20) #xoa theo so
# Out:
#         mssv      ho va ten  khóa khoa  diem
# 0   20146456   nguyễn văn 1    20  ckm     5
# 1   20146148   nguyễn văn 2    20  ckm     4
# 2   20146125   nguyễn văn 3    20  ckm     6
# 3   20146204   nguyễn văn 4    20  ckm     7
# 4   20146235   nguyễn văn 5    20  ckm     8
# 10  20146951  nguyễn văn 11    20  ckm     7
# 11  20146257  nguyễn văn 12    20  ckm     8
# 12  20146146  nguyễn văn 13    20  ckm     9
# 13  20146125  nguyễn văn 14    20  ckm     7
# 14  20146256  nguyễn văn 15    20  ckm     9

# %%
dataframe[dataframe['khóa']!=19].head(20) #xoa theo chu
# Out:
#         mssv      ho va ten  khóa khoa  diem
# 0   20146456   nguyễn văn 1    20  ckm     5
# 1   20146148   nguyễn văn 2    20  ckm     4
# 2   20146125   nguyễn văn 3    20  ckm     6
# 3   20146204   nguyễn văn 4    20  ckm     7
# 4   20146235   nguyễn văn 5    20  ckm     8
# 10  20146951  nguyễn văn 11    20  ckm     7
# 11  20146257  nguyễn văn 12    20  ckm     8
# 12  20146146  nguyễn văn 13    20  ckm     9
# 13  20146125  nguyễn văn 14    20  ckm     7
# 14  20146256  nguyễn văn 15    20  ckm     9

# %%
dataframe[dataframe.index!=4].head(20)  #xoa theo hang
# Out:
#         mssv      ho va ten  khóa khoa  diem
# 0   20146456   nguyễn văn 1    20  ckm     5
# 1   20146148   nguyễn văn 2    20  ckm     4
# 2   20146125   nguyễn văn 3    20  ckm     6
# 3   20146204   nguyễn văn 4    20  ckm     7
# 5   19146789   nguyễn văn 6    19  ckm     9
# 6   19146357   nguyễn văn 7    19  ckm     5
# 7   19146852   nguyễn văn 8    19  ckm     6
# 8   19146357   nguyễn văn 9    19  ckm     8
# 9   19146235  nguyễn văn 10    19  ckm     9
# 10  20146951  nguyễn văn 11    20  ckm     7
# 11  20146257  nguyễn văn 12    20  ckm     8
# 12  20146146  nguyễn văn 13    20  ckm     9
# 13  20146125  nguyễn văn 14    20  ckm     7
# 14  20146256  nguyễn văn 15    20  ckm     9
# 15  19146589  nguyễn văn 16    19  ckm     8
# 16  19146851  nguyễn văn 17    19  ckm     7
# 17  19146539  nguyễn văn 18    19  ckm     6
# 18  19146756  nguyễn văn 19    19  ckm     9
# 19  19146124  nguyễn văn 20    19  ckm    10

# %%
dataframe.groupby('khoa').head(20)
# Out:
#         mssv      ho va ten  khóa khoa  diem
# 0   20146456   nguyễn văn 1    20  ckm     5
# 1   20146148   nguyễn văn 2    20  ckm     4
# 2   20146125   nguyễn văn 3    20  ckm     6
# 3   20146204   nguyễn văn 4    20  ckm     7
# 4   20146235   nguyễn văn 5    20  ckm     8
# 5   19146789   nguyễn văn 6    19  ckm     9
# 6   19146357   nguyễn văn 7    19  ckm     5
# 7   19146852   nguyễn văn 8    19  ckm     6
# 8   19146357   nguyễn văn 9    19  ckm     8
# 9   19146235  nguyễn văn 10    19  ckm     9
# 10  20146951  nguyễn văn 11    20  ckm     7
# 11  20146257  nguyễn văn 12    20  ckm     8
# 12  20146146  nguyễn văn 13    20  ckm     9
# 13  20146125  nguyễn văn 14    20  ckm     7
# 14  20146256  nguyễn văn 15    20  ckm     9
# 15  19146589  nguyễn văn 16    19  ckm     8
# 16  19146851  nguyễn văn 17    19  ckm     7
# 17  19146539  nguyễn văn 18    19  ckm     6
# 18  19146756  nguyễn văn 19    19  ckm     9
# 19  19146124  nguyễn văn 20    19  ckm    10

# %%
dataframe.groupby('khoa').count()
# Out:
#       mssv  ho va ten  khóa  diem
# khoa
# ckm     20         20    20    20

# %%
dataframe.groupby(['khoa', 'khóa']).head(20)
# Out:
#         mssv      ho va ten  khóa khoa  diem
# 0   20146456   nguyễn văn 1    20  ckm     5
# 1   20146148   nguyễn văn 2    20  ckm     4
# 2   20146125   nguyễn văn 3    20  ckm     6
# 3   20146204   nguyễn văn 4    20  ckm     7
# 4   20146235   nguyễn văn 5    20  ckm     8
# 5   19146789   nguyễn văn 6    19  ckm     9
# 6   19146357   nguyễn văn 7    19  ckm     5
# 7   19146852   nguyễn văn 8    19  ckm     6
# 8   19146357   nguyễn văn 9    19  ckm     8
# 9   19146235  nguyễn văn 10    19  ckm     9
# 10  20146951  nguyễn văn 11    20  ckm     7
# 11  20146257  nguyễn văn 12    20  ckm     8
# 12  20146146  nguyễn văn 13    20  ckm     9
# 13  20146125  nguyễn văn 14    20  ckm     7
# 14  20146256  nguyễn văn 15    20  ckm     9
# 15  19146589  nguyễn văn 16    19  ckm     8
# 16  19146851  nguyễn văn 17    19  ckm     7
# 17  19146539  nguyễn văn 18    19  ckm     6
# 18  19146756  nguyễn văn 19    19  ckm     9
# 19  19146124  nguyễn văn 20    19  ckm    10

# %%
dataframe.groupby(['khoa', 'khóa'])['diem'].count()
# Out:
# khoa  khóa
# ckm   19      10
#       20      10
# Name: diem, dtype: int64

# %%
import pandas as pd
import numpy as np

time = pd.date_range('01/01/2023',periods=100000,freq='30s')
dataframe=pd.DataFrame(index=time)
dataframe['Acess_Amount']=np.random.randint(1,10,100000)
dataframe.resample('w').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14479
# 2023-01-08        100940
# 2023-01-15        101126
# 2023-01-22        100500
# 2023-01-29        101000
# 2023-02-05         82063

# %%
import pandas as pd
url= 'http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
print(data)
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
data_del=data.drop(['City','Sport','Event gender','Event'], axis =1)
data_del.groupby('Medal').count()
# Out:
#         Year  Discipline  NOC
# Medal
# Bronze   764         764  764
# Gold     774         774  774
# Silver   773         773  773

# %%
frame = data.set_index(data['NOC'])
frame.loc['USA']
# Out:
#      Year        City       Sport      Discipline  NOC                 Event  \
# NOC
# USA  1924    Chamonix  Ice Hockey      Ice Hockey  USA            ice hockey
# USA  1924    Chamonix     Skating  Figure skating  USA            individual
# USA  1924    Chamonix     Skating   Speed skating  USA                  500m
# USA  1924    Chamonix      Skiing     Ski Jumping  USA  K90 individual (70m)
# USA  1928  St. Moritz   Bobsleigh       Bobsleigh  USA              five-man
# ..    ...         ...         ...             ...  ...                   ...
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
#
#     Event gender   Medal
# NOC
# ...

# %%
frame = data.set_index(data['NOC'])
filter=frame.loc['USA']
filter.groupby('Medal').count()
# Out:
#         Year  City  Sport  Discipline  NOC  Event  Event gender
# Medal
# Bronze    58    58     58          58   58     58            58
# Gold      78    78     78          78   78     78            78
# Silver    80    80     80          80   80     80            80
